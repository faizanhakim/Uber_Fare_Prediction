# %%
import numpy as np
import pandas as pd
import os
import random

# %%
uber = pd.read_csv('uber.csv')
uber.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
uber.shape
# Out:
# (200000, 9)

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
uber.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %% [markdown]
# ## Data Cleaning and EDA

# %%
#check for null values
uber.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
uber_clean = uber.drop(['Unnamed: 0', 'key'],axis = 1)
uber_clean.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
#drop all the null values
uber_clean.dropna(axis =0, inplace = True)

# %%
uber_clean.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
uber_clean.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
def haversine (lon_1, lon_2, lat_1, lat_2):
    lon_1, lon_2, lat_1, lat_2 = map(np.radians, [lon_1, lon_2, lat_1, lat_2])  #Degrees to Radians
    diff_lon = lon_2 - lon_1
    diff_lat = lat_2 - lat_1
    km = 2 * 6371 * np.arcsin(np.sqrt(np.sin(diff_lat/2.0)**2 +
                                      np.cos(lat_1) * np.cos(lat_2) * np.sin(diff_lon/2.0)**2))
    return km

# %%
uber_clean['Distance']= haversine(uber_clean['pickup_longitude'],uber_clean['dropoff_longitude'],
                             uber_clean['pickup_latitude'],uber_clean['dropoff_latitude'])

uber_clean['Distance'] = uber_clean['Distance'].astype(float).round(2)

# %%
uber_clean.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance
# 0         -73.999512         40.723217                1      1.68
# 1         -73.994710         40.750325                1      2.46
# 2         -73.962565         40.772647                1      5.04
# 3         -73.965316         40.803349                3      1.66
# 4         -73.973082         40.761247                5      4.48

# %%
uber_clean.corr(method='pearson', numeric_only=True)
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount           1.000000          0.010458        -0.008482
# pickup_longitude      0.010458          1.000000        -0.816461
# pickup_latitude      -0.008482         -0.816461         1.000000
# dropoff_longitude     0.008986          0.833026        -0.774787
# dropoff_latitude     -0.011014         -0.846324         0.702367
# passenger_count       0.010158         -0.000415        -0.001559
# Distance              0.024684          0.105581        -0.062436
#
#                    dropoff_longitude  dropoff_latitude  passenger_count  \
# fare_amount                 0.008986         -0.011014         0.010158
# pickup_longitude            0.833026         -0.846324        -0.000415
# pickup_latitude            -0.774787          0.702367        -0.001559
# dropoff_longitude           1.000000         -0.917010         0.000033
# dropoff_latitude           -0.917010          1.000000        -0.000659
# passenger_count             0.000033         -0.000659         1.000000
# Distance                    0.056717         -0.079944        -0.001472
#
#                    Distance
# fare_amount        0.024684
# pickup_longitude   0.105581
# pickup_latitude   -0.062436
# dropoff_longitude  0.056717
# dropoff_latitude  -0.079944
# passenger_count   -0.001472
# Distance           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax1, ax = plt.subplots()
dis = uber_clean['Distance']
ax.boxplot(dis)
plt.figure(figsize=(1, 2))
plt.show()

# %%
sns.boxplot(data=uber_clean, x='fare_amount')
plt.show()

# %%
sns.boxplot(data=uber_clean, x='Distance')
plt.show()

# %%
#scatter plot of distance vs fare
import matplotlib.pyplot as plt
plt.scatter(uber_clean['Distance'], uber_clean['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
# Remove outliers
uber_clean.drop(uber_clean[uber_clean['Distance'] > 5].index, inplace = True)
uber_clean.drop(uber_clean[uber_clean['Distance'] == 0].index, inplace = True)
uber_clean.drop(uber_clean[uber_clean['Distance'] < 0].index, inplace = True)

uber_clean.drop(uber_clean[uber_clean['fare_amount'] == 0].index, inplace = True)
uber_clean.drop(uber_clean[uber_clean['fare_amount'] < 0].index, inplace = True)
uber_clean.drop(uber_clean[uber_clean['Distance'] > 100].index, inplace = True)
uber_clean.drop(uber_clean[uber_clean['fare_amount'] > 16].index, inplace = True)
uber_clean.drop(uber_clean[(uber_clean['fare_amount']>100) & (uber_clean['Distance']<1)].index, inplace = True )
uber_clean.drop(uber_clean[(uber_clean['fare_amount']<100) & (uber_clean['Distance']>100)].index, inplace = True )

# %%
uber_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154311 entries, 0 to 199998
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        154311 non-null  float64
#  1   pickup_datetime    154311 non-null  object
#  2   pickup_longitude   154311 non-null  float64
#  3   pickup_latitude    154311 non-null  float64
#  4   dropoff_longitude  154311 non-null  float64
#  5   dropoff_latitude   154311 non-null  float64
#  6   passenger_count    154311 non-null  int64
#  7   Distance           154311 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 10.6+ MB

# %%
sns.boxplot(data=uber_clean, x='Distance')
plt.show()

# %%
sns.boxplot(data=uber_clean, x='fare_amount')
plt.show()

# %%
#if we re plot the scatter plot the change can be observed
plt.scatter(uber_clean['Distance'], uber_clean['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
corr = uber_clean.corr(method='pearson', numeric_only=True)
plt.figure(figsize=(15,15))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Extract date and time
uber_clean['pickup_datetime'] = pd.to_datetime(uber_clean['pickup_datetime'])

uber_clean['Year'] = uber_clean['pickup_datetime'].apply(lambda time: time.year)
uber_clean['Month'] = uber_clean['pickup_datetime'].apply(lambda time: time.month)
uber_clean['Day'] = uber_clean['pickup_datetime'].apply(lambda time: time.day)
uber_clean['Day of Week'] = uber_clean['pickup_datetime'].apply(lambda time: time.dayofweek)
uber_clean['Day of Week_num'] = uber_clean['pickup_datetime'].apply(lambda time: time.dayofweek)
uber_clean['Hour'] = uber_clean['pickup_datetime'].apply(lambda time: time.hour)

day_map = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
uber_clean['Day of Week'] = uber_clean['Day of Week'].map(day_map)

uber_clean['counter'] = 1

# %%
#seperate columns for pickup and dropoff for clear understanding of the data
uber_clean['pickup'] = uber_clean['pickup_latitude'].astype(str) + "," + uber_clean['pickup_longitude'].astype(str)
uber_clean['drop off'] = uber_clean['dropoff_latitude'].astype(str) + "," + uber_clean['dropoff_longitude'].astype(str)

# %%
uber_clean.head(10)
# Out:
#     fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0           7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1           7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 3           5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4          16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
# 8           9.7 2012-02-17 09:32:00+00:00        -73.975187        40.745767
# 9          12.5 2012-03-29 19:06:00+00:00        -74.001065        40.741787
# 10          6.5 2015-05-22 17:32:27+00:00        -73.974388        40.746952
# 12          3.3 2011-05-17 14:03:00+00:00        -73.966378        40.804440
# 13         10.9 2011-06-25 11:19:00+00:00        -73.953352        40.767382
# 14          6.9 2010-04-06 22:20:27+00:00        -73.973370        40.755193
#
#     dropoff_longitude  dropoff_latitude  passenger_count  Distance  Year  \
# 0          -73.999512         40.723217                1      1.68  2015
# 1          -73.994710         40.750325                1      2.46  2009
# 3          -73.965316         40.803349                3      1.66  2009
# 4          -73.973082         40.761247                5      4.48  2014
# 8          -74.002720         40.743537                1      2.33  2012
# 9          -73.963040         40.775012                1      4.89  2012
# 10         -73.988586         40.729805                1      2.25  2015
# 12         -73.965890         40.807133                5      0.30  2011
# 13         -73.972510         40.796137                1      3.58  2011
# 14         -73.978265         40.766375                1      1.31  2010
#
#     Month  Day Day of Week  Day of Week_num  Hour  counter  \
# 0       5    7         Thu                3    19        1
# 1       7   17         Fri                4    20        1
# 3       6   26         Fri                4     8        1
# 4       8   28         Thu                3    17        1
# 8       2   17         Fri                4     9        1
# 9       3   29         Thu                3    19        1
# 10      5   22         Fri                4    17        1
# 12      5   17         Tue                1    14        1
# 13      6   25         Sat                5    11        1
# 14      4    6         Tue                1    22        1
#
#                                   pickup  \
# 0   40.73835372924805,-73.99981689453125
# 1                   40.728225,-73.994355
# 3                   40.790844,-73.976124
# 4                   40.744085,-73.925023
# 8                   40.745767,-73.975187
# 9                   40.741787,-74.001065
# 10   40.74695205688477,-73.9743881225586
# 12                   40.80444,-73.966378
# 13                  40.767382,-73.953352
# 14          40.755193,-73.97336999999999
#
#                                  drop off
# 0       40.72321701049805,-73.99951171875
# 1                     40.750325,-73.99471
# 3                    40.803349,-73.965316
# 4            40.761247,-73.97308199999999
# 8                     40.743537,-74.00272
# 9                     40.775012,-73.96304
# 10  40.729804992675774,-73.98858642578125
# 12                    40.807133,-73.96589
# 13                    40.796137,-73.97251
# 14           40.766375,-73.97826500000001

# %% [markdown]
# ## Data Visualization

# %%
#needed to detect trends in the data to extract useful information for future predictions
trips = []
year = [2009, 2010, 2011, 2012, 2013, 2014, 2015]

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']

for i in range(2009, 2016):
    x = uber_clean.loc[uber_clean['Year'] == i, 'counter'].sum()
    trips.append(x)

plt.title("Average Yearly Trips")
plt.xlabel("Years")
plt.ylabel("Number of Trips")

plt.bar(year, trips, color=colors)
# Out:
# <BarContainer object of 7 artists>

# %%
#monthly trips
trips = []
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']


for i in range(1, 13):
    x = uber_clean.loc[uber_clean['Month'] == i, 'counter'].sum()
    trips.append(x)


plt.title("Average Monthly Trips")
plt.xlabel("Months")
plt.ylabel("Number of Trips")

plt.bar(month, trips, color=colors)
# Out:
# <BarContainer object of 12 artists>

# %%
#Average Daily trips
trips = []
day = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']


for i in range(0, 7):
    x = uber_clean.loc[uber_clean['Day of Week_num'] == i, 'counter'].sum()
    trips.append(x)


plt.title("Average Daily Trips")
plt.xlabel("Days")
plt.ylabel("Number of Trips")

plt.bar(day, trips, color=colors)
# Out:
# <BarContainer object of 7 artists>

# %%
sns.violinplot(data=uber_clean, x='Distance')
plt.show()

# %%
sns.violinplot(data=uber_clean, x='fare_amount')
# Out:
# <Axes: xlabel='fare_amount'>

# %%
year_vs_trips = uber_clean.groupby(['Year','Month']).agg(
    no_of_trips = ('counter','count'),
    Average_fair = ('fare_amount','mean'),
    Total_fair = ('fare_amount','sum'),
    Avg_distance = ( 'Distance', 'mean')).reset_index()

year_vs_trips['avg_no_of_trips'] = year_vs_trips['no_of_trips']/30
year_vs_trips['month_year'] = year_vs_trips['Month'].astype(str) +", "+ year_vs_trips['Year'].astype(str)


year_vs_trips = year_vs_trips.reset_index()

year_vs_trips.head()
# Out:
#    index  Year  Month  no_of_trips  Average_fair  Total_fair  Avg_distance  \
# 0      0  2009      1         2059      7.247644    14922.90      1.973798
# 1      1  2009      2         1873      7.281020    13637.35      2.005611
# 2      2  2009      3         2146      7.308388    15683.80      2.035513
# 3      3  2009      4         2073      7.454896    15454.00      2.050955
# 4      4  2009      5         2132      7.284850    15531.30      2.036459
#
#    avg_no_of_trips month_year
# 0        68.633333    1, 2009
# 1        62.433333    2, 2009
# 2        71.533333    3, 2009
# 3        69.100000    4, 2009
# 4        71.066667    5, 2009

# %%
year_vs_trips.plot(figsize= (10,6),kind='line',x='month_year',y='no_of_trips', xlabel='January, 2009 - June, 2015',
    ylabel='No of Trips', title='No of trips vs Months')
# Out:
# <Axes: title={'center': 'No of trips vs Months'}, xlabel='January, 2009 - June, 2015', ylabel='No of Trips'>

# %% [markdown]
# ## **Model Training**

# %%
import tensorflow as tf
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

# %%
uber_clean.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
# 8          9.7 2012-02-17 09:32:00+00:00        -73.975187        40.745767
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance  Year  \
# 0         -73.999512         40.723217                1      1.68  2015
# 1         -73.994710         40.750325                1      2.46  2009
# 3         -73.965316         40.803349                3      1.66  2009
# 4         -73.973082         40.761247                5      4.48  2014
# 8         -74.002720         40.743537                1      2.33  2012
#
#    Month  Day Day of Week  Day of Week_num  Hour  counter  \
# 0      5    7         Thu                3    19        1
# 1      7   17         Fri                4    20        1
# 3      6   26         Fri                4     8        1
# 4      8   28         Thu                3    17        1
# 8      2   17         Fri                4     9        1
#
#                                  pickup                           drop off
# 0  40.73835372924805,-73.99981689453125  40.72321701049805,-73.99951171875
# 1                  40.728225,-73.994355                40.750325,-73.99471
# 3                  40.790844,-73.976124               40.803349,-73.965316
# 4                  40.744085,-73.925023       40.761247,-73.97308199999999
# 8                  40.745767,-73.975187                40.743537,-74.00272

# %%
uber_clean.drop(['pickup_datetime', 'pickup', 'drop off', 'counter', 'Day of Week',
                 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude','dropoff_latitude', 'passenger_count'], axis=1, inplace=True)

# %%
uber_clean.head()
# Out:
#    fare_amount  Distance  Year  Month  Day  Day of Week_num  Hour
# 0          7.5      1.68  2015      5    7                3    19
# 1          7.7      2.46  2009      7   17                4    20
# 3          5.3      1.66  2009      6   26                4     8
# 4         16.0      4.48  2014      8   28                3    17
# 8          9.7      2.33  2012      2   17                4     9

# %%
uber_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154311 entries, 0 to 199998
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   fare_amount      154311 non-null  float64
#  1   Distance         154311 non-null  float64
#  2   Year             154311 non-null  int64
#  3   Month            154311 non-null  int64
#  4   Day              154311 non-null  int64
#  5   Day of Week_num  154311 non-null  int64
#  6   Hour             154311 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 9.4 MB

# %%
uber_clean.reset_index(inplace=True)

# %%
uber_clean.drop(['index'], axis=1, inplace=True)

# %%
target_name = 'fare_amount'
feature_names = [column for column in uber_clean.columns if column != target_name]

# %%
# Seperate Test and Train set
X = uber_clean[feature_names]
y = uber_clean[[target_name]]

# %%
X
# Out:
#         Distance  Year  Month  Day  Day of Week_num  Hour
# 0           1.68  2015      5    7                3    19
# 1           2.46  2009      7   17                4    20
# 2           1.66  2009      6   26                4     8
# 3           4.48  2014      8   28                3    17
# 4           2.33  2012      2   17                4     9
# ...          ...   ...    ...  ...              ...   ...
# 154306      2.64  2012      9   29                5    19
# 154307      1.12  2014      1   31                4    14
# 154308      0.11  2012     10   28                6    10
# 154309      1.88  2014      3   14                4     1
# 154310      3.54  2015      5   20                2    14
#
# [154311 rows x 6 columns]

# %%
X_norm = Normalizer().fit_transform(X)

# %% [markdown]
# ### Test Train Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_norm, np.squeeze(y), test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((123448, 6), (30863, 6), (123448,), (30863,))

# %%
sns.scatterplot(x=X_train[:, 0], y=y_train, label='train data', color='blue')
sns.scatterplot(x=X_test[:, 0], y=y_test, label='test data', color='green')
plt.legend()
plt.show()
# Out:
# C:\Users\Faizan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Neural Network Model

# %%
def reset_random_seeds(seed):
   os.environ['PYTHONHASHSEED']=str(seed)
   tf.random.set_seed(seed)
   tf.keras.utils.set_random_seed(seed)
   np.random.seed(seed)
   random.seed(seed)

# %%
i_shape = X_norm.shape[1]

# %% [markdown]
# ### Model 1

# %%
reset_random_seeds(42)
model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, input_shape=(i_shape,), activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    tf.keras.layers.Dense(1, activation='relu')
])

# %%
model1.compile(loss=tf.keras.losses.Huber(delta=1.0),
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               700
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='loss',
    patience=3,
    restore_best_weights=True
)

# %%
history = model1.fit(X_train, y_train, epochs=50, batch_size=150, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/50
# 823/823 [==============================] - 11s 9ms/step - loss: 2.4816 - mean_squared_error: 14.7938 - mean_absolute_error: 2.9447
# Epoch 2/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.8799 - mean_squared_error: 8.5920 - mean_absolute_error: 2.3373
# Epoch 3/50
# 823/823 [==============================] - 7s 9ms/step - loss: 1.8752 - mean_squared_error: 8.5553 - mean_absolute_error: 2.3326
# Epoch 4/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.8698 - mean_squared_error: 8.5167 - mean_absolute_error: 2.3272
# Epoch 5/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.8631 - mean_squared_error: 8.4683 - mean_absolute_error: 2.3204
# Epoch 6/50
# 823/823 [==============================] - 6s 8ms/step - loss: 1.8545 - mean_squared_error: 8.4130 - mean_absolute_error: 2.3114
# Epoch 7/50
# 823/823 [==============================] - 6s 7ms/step - loss: 1.8435 - mean_squared_error: 8.3317 - mean_absolute_error: 2.3003
# Epoch 8/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.8270 - mean_squared_error: 8.2228 - mean_absolute_error: 2.2835
# Epoch 9/50
# 823/823 [==============================] - 6s 8ms/step - loss: 1.8043 - mean_squared_error: 8.0675 - mean_absolute_error: 2.2603
# Epoch 10/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.7758 - mean_squared_error: 7.8793 - mean_absolute_error: 2.2312
# Epoch 11/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.7371 - mean_squared_error: 7.6234 - mean_absolute_error: 2.1916
# Epoch 12/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.6875 - mean_squared_error: 7.3072 - mean_absolute_error: 2.1406
# Epoch 13/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.6245 - mean_squared_error: 6.9138 - mean_absolute_error: 2.0758
# Epoch 14/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.5504 - mean_squared_error: 6.4688 - mean_absolute_error: 1.9996
# Epoch 15/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.4641 - mean_squared_error: 5.9792 - mean_absolute_error: 1.9102
# Epoch 16/50
# 823/823 [==============================] - 6s 8ms/step - loss: 1.3699 - mean_squared_error: 5.4682 - mean_absolute_error: 1.8125
# Epoch 17/50
# 823/823 [==============================] - 7s 9ms/step - loss: 1.2732 - mean_squared_error: 4.9726 - mean_absolute_error: 1.7116
# Epoch 18/50
# 823/823 [==============================] - 7s 8ms/step - loss: 1.1786 - mean_squared_error: 4.5191 - mean_absolute_error: 1.6122
# Epoch 19/50
# 823/823 [==============================] - 6s 8ms/step - loss: 1.1008 - mean_squared_error: 4.1700 - mean_absolute_error: 1.5301
# Epoch 20/50
# 823/823 [==============================] - 7s 9ms/step - loss: 1.0404 - mean_squared_error: 3.9148 - mean_absolute_error: 1.4650
# Epoch 21/50
# 823/823 [==============================] - 8s 9ms/step - loss: 1.0024 - mean_squared_error: 3.7634 - mean_absolute_error: 1.4232
# Epoch 22/50
# 823/823 [==============================] - 7s 9ms/step - loss: 0.9799 - mean_squared_error: 3.6799 - mean_absolute_error: 1.3981
# Epoch 23/50
# 823/823 [==============================] - 7s 8ms/step - loss: 0.9670 - mean_squared_error: 3.6388 - mean_absolute_error: 1.3833
# Epoch 24/50
# 823/823 [==============================] - 6s 8ms/step - loss: 0.9645 - mean_squared_error: 3.6355 - mean_absolute_error: 1.3798
# Epoch 25/50
# 823/823 [==============================] - 6s 8ms/step - loss: 0.9616 - mean_squared_error: 3.6298 - mean_absolute_error: 1.3761
# Epoch 26/50
# 823/823 [==============================] - 7s 8ms/step - loss: 0.9633 - mean_squared_error: 3.6366 - mean_absolute_error: 1.3775
# Epoch 27/50
# 823/823 [==============================] - 6s 7ms/step - loss: 0.9609 - mean_squared_error: 3.6282 - mean_absolute_error: 1.3747
# Epoch 28/50
# 823/823 [==============================] - 6s 8ms/step - loss: 0.9614 - mean_squared_error: 3.6317 - mean_absolute_error: 1.3753
# Epoch 29/50
# 823/823 [==============================] - 7s 9ms/step - loss: 0.9612 - mean_squared_error: 3.6318 - mean_absolute_error: 1.3751
# Epoch 30/50
# 823/823 [==============================] - 7s 8ms/step - loss: 0.9618 - mean_squared_error: 3.6342 - mean_absolute_error: 1.3757

# %%
pd.DataFrame(history.history).plot()

# %%
model1.evaluate(X_test, y_test)
# Out:
# 965/965 [==============================] - 4s 4ms/step - loss: 0.9423 - mean_squared_error: 3.5486 - mean_absolute_error: 1.3552
# [0.9423270225524902, 3.548583507537842, 1.3552415370941162]

# %%
y_pred = model1.predict(X_test)

fig, axes = plt.subplots(1, 3, figsize=(12, 5))

# Plot the first scatter plot on the first subplot
sns.scatterplot(x=X_test[:, 0], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[0])
axes[0].set_title('Predicted')

# Plot the second scatter plot on the second subplot
sns.scatterplot(x=X_test[:,0], y=y_test, label='Actual', color='green', ax=axes[1])
axes[1].set_title('Actual')

sns.scatterplot(x=X_test[:,0], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[2])
sns.scatterplot(x=X_test[:,0], y=y_test, label='Actual', color='green', ax=axes[2])
axes[2].set_title('Predicted v Actual')


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Model 2

# %%
reset_random_seeds(42)
model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(40, input_shape=(1,), activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(1, activation='relu')
])

# %%
model2.compile(loss='mean_squared_error',
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=['mean_squared_error', 'mean_absolute_error'])

#keras.losses.Huber(delta=1.0),

# %%
history = model2.fit(X_train, y_train, epochs=50, batch_size=100, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 10.2409 - mean_squared_error: 10.2409 - mean_absolute_error: 2.5208
# Epoch 2/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.9477 - mean_squared_error: 3.9477 - mean_absolute_error: 1.5036
# Epoch 3/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 3.8087 - mean_squared_error: 3.8087 - mean_absolute_error: 1.4695
# Epoch 4/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.7764 - mean_squared_error: 3.7764 - mean_absolute_error: 1.4639
# Epoch 5/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.7205 - mean_squared_error: 3.7205 - mean_absolute_error: 1.4523
# Epoch 6/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6882 - mean_squared_error: 3.6882 - mean_absolute_error: 1.4461
# Epoch 7/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6906 - mean_squared_error: 3.6906 - mean_absolute_error: 1.4501
# Epoch 8/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6730 - mean_squared_error: 3.6730 - mean_absolute_error: 1.4469
# Epoch 9/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6729 - mean_squared_error: 3.6729 - mean_absolute_error: 1.4456
# Epoch 10/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6731 - mean_squared_error: 3.6731 - mean_absolute_error: 1.4455
# Epoch 11/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6590 - mean_squared_error: 3.6590 - mean_absolute_error: 1.4418
# Epoch 12/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6499 - mean_squared_error: 3.6499 - mean_absolute_error: 1.4413
# Epoch 13/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6724 - mean_squared_error: 3.6724 - mean_absolute_error: 1.4451
# Epoch 14/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6509 - mean_squared_error: 3.6509 - mean_absolute_error: 1.4405
# Epoch 15/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 3.6465 - mean_squared_error: 3.6465 - mean_absolute_error: 1.4397
# Epoch 16/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6589 - mean_squared_error: 3.6589 - mean_absolute_error: 1.4421
# Epoch 17/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6547 - mean_squared_error: 3.6547 - mean_absolute_error: 1.4420
# Epoch 18/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6476 - mean_squared_error: 3.6476 - mean_absolute_error: 1.4394
# Epoch 19/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6296 - mean_squared_error: 3.6296 - mean_absolute_error: 1.4358
# Epoch 20/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6450 - mean_squared_error: 3.6450 - mean_absolute_error: 1.4394
# Epoch 21/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6312 - mean_squared_error: 3.6312 - mean_absolute_error: 1.4356
# Epoch 22/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6313 - mean_squared_error: 3.6313 - mean_absolute_error: 1.4368
# Epoch 23/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6171 - mean_squared_error: 3.6171 - mean_absolute_error: 1.4317
# Epoch 24/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6264 - mean_squared_error: 3.6264 - mean_absolute_error: 1.4342
# Epoch 25/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6062 - mean_squared_error: 3.6062 - mean_absolute_error: 1.4302
# Epoch 26/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6083 - mean_squared_error: 3.6083 - mean_absolute_error: 1.4310
# Epoch 27/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.6027 - mean_squared_error: 3.6027 - mean_absolute_error: 1.4290
# Epoch 28/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5931 - mean_squared_error: 3.5931 - mean_absolute_error: 1.4273
# Epoch 29/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5933 - mean_squared_error: 3.5933 - mean_absolute_error: 1.4268
# Epoch 30/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5936 - mean_squared_error: 3.5936 - mean_absolute_error: 1.4266
# Epoch 31/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5933 - mean_squared_error: 3.5933 - mean_absolute_error: 1.4269
# Epoch 32/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5826 - mean_squared_error: 3.5826 - mean_absolute_error: 1.4240
# Epoch 33/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 3.5883 - mean_squared_error: 3.5883 - mean_absolute_error: 1.4254
# Epoch 34/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5882 - mean_squared_error: 3.5882 - mean_absolute_error: 1.4253
# Epoch 35/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5770 - mean_squared_error: 3.5770 - mean_absolute_error: 1.4229
# Epoch 36/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5808 - mean_squared_error: 3.5808 - mean_absolute_error: 1.4247
# Epoch 37/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5761 - mean_squared_error: 3.5761 - mean_absolute_error: 1.4222
# Epoch 38/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5737 - mean_squared_error: 3.5737 - mean_absolute_error: 1.4228
# Epoch 39/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5744 - mean_squared_error: 3.5744 - mean_absolute_error: 1.4216
# Epoch 40/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 3.5765 - mean_squared_error: 3.5765 - mean_absolute_error: 1.4219
# Epoch 41/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5567 - mean_squared_error: 3.5567 - mean_absolute_error: 1.4178
# Epoch 42/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5821 - mean_squared_error: 3.5821 - mean_absolute_error: 1.4254
# Epoch 43/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5746 - mean_squared_error: 3.5746 - mean_absolute_error: 1.4221
# Epoch 44/50
# 1235/1235 [==============================] - 7s 5ms/step - loss: 3.5664 - mean_squared_error: 3.5664 - mean_absolute_error: 1.4203
# Epoch 45/50
# 1235/1235 [==============================] - 6s 5ms/step - loss: 3.5600 - mean_squared_error: 3.5600 - mean_absolute_error: 1.4188
# Epoch 46/50
# 1235/1235 [==============================] - 5s 4ms/step - loss: 3.5657 - mean_squared_error: 3.5657 - mean_absolute_error: 1.4210

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
model2.evaluate(X_test, y_test)
# Out:
# 965/965 [==============================] - 2s 2ms/step - loss: 3.5200 - mean_squared_error: 3.5200 - mean_absolute_error: 1.3679
# [3.5199902057647705, 3.5199902057647705, 1.3679391145706177]

# %%
y_pred = model2.predict(X_test)
fig, axes = plt.subplots(1, 3, figsize=(12, 5))

# Plot the first scatter plot on the first subplot
sns.scatterplot(x=X_test[:], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[0])
axes[0].set_title('Predicted')

# Plot the second scatter plot on the second subplot
sns.scatterplot(x=X_test[:], y=y_test, label='Actual', color='green', ax=axes[1])
axes[1].set_title('Actual')

sns.scatterplot(x=X_test[:], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[2])
sns.scatterplot(x=X_test[:], y=y_test, label='Actual', color='green', ax=axes[2])
axes[2].set_title('Predicted v Actual')


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# 965/965 [==============================] - 2s 2ms/step

# %% [markdown]
# ### Model 3

# %%
reset_random_seeds(42)
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(5000, input_shape=(i_shape,), activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(5000, activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    # tf.keras.layers.Dropout(0.1),
    # tf.keras.layers.Dense(1500, activation='relu'),
    # tf.keras.layers.Dropout(0.2),
    # tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(1, activation=tf.keras.layers.LeakyReLU(alpha=0.01))
])

model3.compile(loss=tf.keras.losses.Huber(delta=0.2),
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=['mean_squared_error', 'mean_absolute_error'])



#tf.keras.losses.Huber(delta=1.0)
history = model3.fit(X_train, y_train, epochs=50, batch_size=800,  callbacks=[early_stopping_callback])
# Out:
# Epoch 1/50
# 155/155 [==============================] - 4s 23ms/step - loss: 0.4733 - mean_squared_error: 9.8025 - mean_absolute_error: 2.4650
# Epoch 2/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.4427 - mean_squared_error: 8.4354 - mean_absolute_error: 2.3120
# Epoch 3/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.4075 - mean_squared_error: 7.3259 - mean_absolute_error: 2.1356
# Epoch 4/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.3535 - mean_squared_error: 5.8373 - mean_absolute_error: 1.8651
# Epoch 5/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2982 - mean_squared_error: 4.4572 - mean_absolute_error: 1.5880
# Epoch 6/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2708 - mean_squared_error: 3.9102 - mean_absolute_error: 1.4507
# Epoch 7/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2642 - mean_squared_error: 3.8073 - mean_absolute_error: 1.4178
# Epoch 8/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2637 - mean_squared_error: 3.7958 - mean_absolute_error: 1.4153
# Epoch 9/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2603 - mean_squared_error: 3.7467 - mean_absolute_error: 1.3980
# Epoch 10/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2650 - mean_squared_error: 3.8148 - mean_absolute_error: 1.4216
# Epoch 11/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2614 - mean_squared_error: 3.7540 - mean_absolute_error: 1.4035
# Epoch 12/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2582 - mean_squared_error: 3.7081 - mean_absolute_error: 1.3878
# Epoch 13/50
# 155/155 [==============================] - 3s 21ms/step - loss: 0.2587 - mean_squared_error: 3.7167 - mean_absolute_error: 1.3900
# Epoch 14/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2608 - mean_squared_error: 3.7540 - mean_absolute_error: 1.4006
# Epoch 15/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2611 - mean_squared_error: 3.7484 - mean_absolute_error: 1.4022
# Epoch 16/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2609 - mean_squared_error: 3.7529 - mean_absolute_error: 1.4008
# Epoch 17/50
# 155/155 [==============================] - 3s 20ms/step - loss: 0.2583 - mean_squared_error: 3.7028 - mean_absolute_error: 1.3878

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
model3.evaluate(X_test, y_test)
# Out:
# 965/965 [==============================] - 6s 6ms/step - loss: 0.2551 - mean_squared_error: 3.8218 - mean_absolute_error: 1.3717
# [0.25512945652008057, 3.821755886077881, 1.3716506958007812]

# %%
y_pred = model3.predict(X_test)
fig, axes = plt.subplots(1, 3, figsize=(12, 5))

# Plot the first scatter plot on the first subplot
sns.scatterplot(x=X_test[:, 1], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[0])
axes[0].set_title('Predicted')

# Plot the second scatter plot on the second subplot
sns.scatterplot(x=X_test[:,1], y=y_test, label='Actual', color='green', ax=axes[1])
axes[1].set_title('Actual')

sns.scatterplot(x=X_test[:,1], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[2])
sns.scatterplot(x=X_test[:,1], y=y_test, label='Actual', color='green', ax=axes[2])
axes[2].set_title('Predicted v Actual')


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# 965/965 [==============================] - 2s 2ms/step

# %% [markdown]
# ## Using K-Fold

# %%
reset_random_seeds(42)
model4 = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, input_shape=(i_shape,), activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(1000, activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1000, activation=tf.keras.layers.LeakyReLU(alpha=0.01)),
    # tf.keras.layers.Dropout(0.2),
    # tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

model4.compile(loss=tf.keras.losses.Huber(delta=0.2),
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.003),
               metrics=['mean_squared_error', 'mean_absolute_error'])

# %%
X_d = pd.DataFrame(X_train)
y_d = pd.DataFrame(y_train)

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
histories = []
# Iterate through each fold
for train_idx, val_idx in kfold.split(X_train):
     # Split data into train and validation sets
    X_temp, X_val = X_d.iloc[train_idx], X_d.iloc[val_idx]
    y_temp, y_val = y_d.iloc[train_idx], y_d.iloc[val_idx]
    
    history = model4.fit(X_temp, y_temp, epochs=50, batch_size=150,  callbacks=[early_stopping_callback])
    pd.DataFrame(history.history).plot()
    histories.append(history)
    model4.evaluate(X_val, y_val)
    
    #print("Train indices:", train_idx)
    #print("Validation indices:", val_idx)
    #print()
# Out:
# Epoch 1/50
# 659/659 [==============================] - 8s 11ms/step - loss: 0.4295 - mean_squared_error: 8.1697 - mean_absolute_error: 2.2457
# Epoch 2/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2927 - mean_squared_error: 4.3799 - mean_absolute_error: 1.5603
# Epoch 3/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2728 - mean_squared_error: 3.9788 - mean_absolute_error: 1.4605
# Epoch 4/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2668 - mean_squared_error: 3.8632 - mean_absolute_error: 1.4309
# Epoch 5/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2685 - mean_squared_error: 3.8908 - mean_absolute_error: 1.4395
# Epoch 6/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2693 - mean_squared_error: 3.8932 - mean_absolute_error: 1.4431
# Epoch 7/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2667 - mean_squared_error: 3.8516 - mean_absolute_error: 1.4302
# Epoch 8/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2717 - mean_squared_error: 3.9460 - mean_absolute_error: 1.4550
# Epoch 9/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2640 - mean_squared_error: 3.8028 - mean_absolute_error: 1.4163
# Epoch 10/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2655 - mean_squared_error: 3.8256 - mean_absolute_error: 1.4238
# Epoch 11/50
# 659/659 [==============================] - 4s 7ms/step - loss: 0.2637 - mean_squared_error: 3.7855 - mean_absolute_error: 1.4149
# Epoch 12/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2648 - mean_squared_error: 3.8099 - mean_absolute_error: 1.4207
# Epoch 13/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2655 - mean_squared_error: 3.8237 - mean_absolute_error: 1.4240
# Epoch 14/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2635 - mean_squared_error: 3.7855 - mean_absolute_error: 1.4139
# Epoch 15/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2636 - mean_squared_error: 3.7828 - mean_absolute_error: 1.4144
# Epoch 16/50
# 659/659 [==============================] - 7s 10ms/step - loss: 0.2646 - mean_squared_error: 3.8022 - mean_absolute_error: 1.4195
# Epoch 17/50
# 659/659 [==============================] - 6s 9ms/step - loss: 0.2634 - mean_squared_error: 3.7799 - mean_absolute_error: 1.4135
# Epoch 18/50
# 659/659 [==============================] - 4s 7ms/step - loss: 0.2636 - mean_squared_error: 3.7849 - mean_absolute_error: 1.4148
# Epoch 19/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2621 - mean_squared_error: 3.7620 - mean_absolute_error: 1.4071
# Epoch 20/50
# 659/659 [==============================] - 6s 8ms/step - loss: 0.2620 - mean_squared_error: 3.7554 - mean_absolute_error: 1.4066
# Epoch 21/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2626 - mean_squared_error: 3.7625 - mean_absolute_error: 1.4094
# Epoch 22/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2638 - mean_squared_error: 3.7879 - mean_absolute_error: 1.4155
# Epoch 23/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2641 - mean_squared_error: 3.7899 - mean_absolute_error: 1.4168
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2686 - mean_squared_error: 4.2024 - mean_absolute_error: 1.4389
# Epoch 1/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2624 - mean_squared_error: 3.7531 - mean_absolute_error: 1.4083
# Epoch 2/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2614 - mean_squared_error: 3.7438 - mean_absolute_error: 1.4036
# Epoch 3/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2602 - mean_squared_error: 3.7159 - mean_absolute_error: 1.3975
# Epoch 4/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2623 - mean_squared_error: 3.7571 - mean_absolute_error: 1.4083
# Epoch 5/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2622 - mean_squared_error: 3.7527 - mean_absolute_error: 1.4077
# Epoch 6/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2607 - mean_squared_error: 3.7275 - mean_absolute_error: 1.4001
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2571 - mean_squared_error: 3.8142 - mean_absolute_error: 1.3816
# Epoch 1/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2618 - mean_squared_error: 3.7383 - mean_absolute_error: 1.4057
# Epoch 2/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2627 - mean_squared_error: 3.7482 - mean_absolute_error: 1.4101
# Epoch 3/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2601 - mean_squared_error: 3.7052 - mean_absolute_error: 1.3971
# Epoch 4/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2613 - mean_squared_error: 3.7234 - mean_absolute_error: 1.4029
# Epoch 5/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2620 - mean_squared_error: 3.7333 - mean_absolute_error: 1.4063
# Epoch 6/50
# 659/659 [==============================] - 4s 7ms/step - loss: 0.2599 - mean_squared_error: 3.7032 - mean_absolute_error: 1.3960
# Epoch 7/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2593 - mean_squared_error: 3.6903 - mean_absolute_error: 1.3928
# Epoch 8/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2588 - mean_squared_error: 3.6872 - mean_absolute_error: 1.3906
# Epoch 9/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2608 - mean_squared_error: 3.7153 - mean_absolute_error: 1.4007
# Epoch 10/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2603 - mean_squared_error: 3.7061 - mean_absolute_error: 1.3981
# Epoch 11/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2606 - mean_squared_error: 3.7120 - mean_absolute_error: 1.3995
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2644 - mean_squared_error: 3.5483 - mean_absolute_error: 1.4190
# Epoch 1/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2591 - mean_squared_error: 3.6936 - mean_absolute_error: 1.3920
# Epoch 2/50
# 659/659 [==============================] - 5s 7ms/step - loss: 0.2611 - mean_squared_error: 3.7248 - mean_absolute_error: 1.4022
# Epoch 3/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2613 - mean_squared_error: 3.7402 - mean_absolute_error: 1.4032
# Epoch 4/50
# 659/659 [==============================] - 7s 11ms/step - loss: 0.2611 - mean_squared_error: 3.7292 - mean_absolute_error: 1.4020
# 772/772 [==============================] - 5s 6ms/step - loss: 0.2610 - mean_squared_error: 3.5085 - mean_absolute_error: 1.4018
# Epoch 1/50
# 659/659 [==============================] - 6s 9ms/step - loss: 0.2587 - mean_squared_error: 3.6823 - mean_absolute_error: 1.3899
# Epoch 2/50
# 659/659 [==============================] - 6s 8ms/step - loss: 0.2603 - mean_squared_error: 3.7104 - mean_absolute_error: 1.3978
# Epoch 3/50
# 659/659 [==============================] - 6s 10ms/step - loss: 0.2584 - mean_squared_error: 3.6773 - mean_absolute_error: 1.3884
# Epoch 4/50
# 659/659 [==============================] - 6s 9ms/step - loss: 0.2586 - mean_squared_error: 3.6827 - mean_absolute_error: 1.3897
# Epoch 5/50
# 659/659 [==============================] - 6s 9ms/step - loss: 0.2591 - mean_squared_error: 3.6912 - mean_absolute_error: 1.3920
# Epoch 6/50
# 659/659 [==============================] - 6s 8ms/step - loss: 0.2582 - mean_squared_error: 3.6675 - mean_absolute_error: 1.3877
# Epoch 7/50
# 659/659 [==============================] - 7s 10ms/step - loss: 0.2593 - mean_squared_error: 3.6904 - mean_absolute_error: 1.3930
# Epoch 8/50
# 659/659 [==============================] - 5s 8ms/step - loss: 0.2588 - mean_squared_error: 3.6843 - mean_absolute_error: 1.3904
# Epoch 9/50
# 659/659 [==============================] - 4s 7ms/step - loss: 0.2595 - mean_squared_error: 3.6962 - mean_absolute_error: 1.3941
# 772/772 [==============================] - 4s 5ms/step - loss: 0.2554 - mean_squared_error: 3.5622 - mean_absolute_error: 1.3738

# %%
y_pred = model4.predict(X_test)
fig, axes = plt.subplots(1, 3, figsize=(12, 5))

# Plot the first scatter plot on the first subplot
sns.scatterplot(x=X_test[:, 1], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[0])
axes[0].set_title('Predicted')

# Plot the second scatter plot on the second subplot
sns.scatterplot(x=X_test[:,1], y=y_test, label='Actual', color='green', ax=axes[1])
axes[1].set_title('Actual')

sns.scatterplot(x=X_test[:,1], y=np.squeeze(y_pred), label='Predicted', color='red', ax=axes[2])
sns.scatterplot(x=X_test[:,1], y=y_test, label='Actual', color='green', ax=axes[2])
axes[2].set_title('Predicted v Actual')


# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
